# %%
import os
import random
import torch
import torchaudio
import numpy as np
import librosa
import soundfile as sf

TARGET_SAMPLE_RATE = 16000
MAX_SECONDS = 15
MAX_SAMPLES = TARGET_SAMPLE_RATE * MAX_SECONDS

def load_musan_noises(musan_dir):
    noise_files = []
    for subdir in ['noise', 'music', 'speech']:
        subpath = os.path.join(musan_dir, subdir)
        if os.path.exists(subpath):
            for root, _, files in os.walk(subpath):
                for file in files:
                    if file.endswith('.wav'):
                        noise_files.append(os.path.join(root, file))
    return noise_files

def add_background_noise(signal, sample_rate, noise_files, snr_db_range=(0, 15)):
    if not noise_files:
        return signal
    
    noise_path = random.choice(noise_files)
    noise, noise_sr = torchaudio.load(noise_path)
    
    if noise_sr != sample_rate:
        noise = torchaudio.transforms.Resample(noise_sr, sample_rate)(noise)
    
    sig_len = signal.shape[1]
    noise_len = noise.shape[1]

    if noise_len > sig_len:
        start = random.randint(0, noise_len - sig_len)
        noise = noise[:, start:start + sig_len]
    elif noise_len < sig_len:
        pad_left = random.randint(0, sig_len - noise_len)
        pad_right = sig_len - noise_len - pad_left
        noise = torch.nn.functional.pad(noise, (pad_left, pad_right))
    
    # Compute SNR
    snr_db = random.uniform(*snr_db_range)
    signal_power = torch.mean(signal ** 2)
    noise_power = torch.mean(noise ** 2)
    factor = torch.sqrt(signal_power / (noise_power * 10 ** (snr_db / 10)))
    noise.mul_(factor)  # in-place
    signal.add_(noise)  # in-place
    signal.div_(torch.max(torch.abs(signal)))  # normalize in-place
    return signal

def time_stretch(signal, rate):
    signal_np = signal.numpy().flatten()
    stretched = librosa.effects.time_stretch(signal_np, rate=rate)
    return torch.tensor(stretched, dtype=torch.float32).unsqueeze(0)

def apply_manual_gain(signal, gain_db):
    gain_linear = 10 ** (gain_db / 20)
    signal.mul_(gain_linear)  # in-place
    return signal

def augment_audio(audio_path, musan_noises, output_dir):
    signal, orig_sr = torchaudio.load(audio_path)
    
    # Resample if needed
    if orig_sr != TARGET_SAMPLE_RATE:
        signal = torchaudio.transforms.Resample(orig_sr, TARGET_SAMPLE_RATE)(signal)
    
    # Trim long audio
    if signal.shape[1] > MAX_SAMPLES:
        signal = signal[:, :MAX_SAMPLES]

    # Augmentations
    if random.random() < 0.5:
        signal = add_background_noise(signal, TARGET_SAMPLE_RATE, musan_noises)

    if random.random() < 0.5:
        pitch_shift = random.uniform(-4, 4)
        signal = torchaudio.functional.pitch_shift(signal, TARGET_SAMPLE_RATE, n_steps=pitch_shift)
    
    if random.random() < 0.5:
        rate = random.uniform(0.8, 1.2)
        signal = time_stretch(signal, rate)
    
    if random.random() < 0.5:
        gain_db = random.uniform(-6, 6)
        signal = apply_manual_gain(signal, gain_db)
    
    if random.random() < 0.3:
        noise = torch.normal(0, random.uniform(0.001, 0.015), signal.shape)
        signal.add_(noise)
        signal.div_(torch.max(torch.abs(signal)))  # normalize

    # Save augmented file
    base_name = os.path.basename(audio_path)
    output_path = os.path.join(output_dir, f"aug_{base_name}")
    sf.write(output_path, signal.numpy().flatten(), TARGET_SAMPLE_RATE)

    # Free memory
    del signal
    torch.cuda.empty_cache()
    
    return output_path

def main(input_dir, musan_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    musan_noises = load_musan_noises(musan_dir)
    if not musan_noises:
        print("Warning: No MUSAN noise files found. Skipping background noise augmentation.")
    
    # Recursively gather all WAV files
    wav_files = []
    for root, _, files in os.walk(input_dir):
        for file in files:
            if file.endswith('.wav'):
                wav_files.append(os.path.join(root, file))
    
    print(f"Found {len(wav_files)} WAV files to augment.")

    for idx, audio_path in enumerate(wav_files, 1):
        try:
            augmented_path = augment_audio(audio_path, musan_noises, output_dir)
            print(f"[{idx}/{len(wav_files)}] Augmented and saved: {augmented_path}")
        except Exception as e:
            print(f"[{idx}/{len(wav_files)}] Error processing {audio_path}: {e}")

if __name__ == "__main__":
    musan_dir = "/Users/sethwright/Downloads/musan"
    input_dir = "/Users/sethwright/Documents/audio-model/data/negative"
    output_dir = "/Users/sethwright/Documents/audio-model/data/Training_NEG"
    main(input_dir, musan_dir, output_dir)
# Out:
# Found 16296 WAV files to augment.
# [1/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4278_negative_background.wav
# [2/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706161_chunk005.wav
# [3/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710667_chunk002.wav
# [4/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_37e8db82_nohash_1.wav
# [5/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713346_chunk006.wav
# [6/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2024_negative_background.wav
# [7/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43214794_chunk002.wav
# [8/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706134_chunk005.wav
# [9/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710632_chunk002.wav
# [10/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42711332_chunk002.wav
# [11/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3636_negative_background.wav
# [12/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5166_negative_background.wav
# [13/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710626_chunk004.wav
# [14/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706120_chunk003.wav
# [15/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43214780_chunk004.wav
# [16/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4774_negative_background.wav
# [17/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42817029_chunk005.wav
# [18/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710698_chunk002.wav
# [19/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_1eddce1d_nohash_3.wav
# [20/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415535_chunk007.wav
# [21/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42707475_chunk003.wav
# [22/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710673_chunk004.wav
# [23/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2528_negative_background.wav
# [24/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706175_chunk003.wav
# [25/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5984_negative_background.wav
# [26/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42703602_chunk008.wav
# [27/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713197_chunk004.wav
# [28/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording441.wav
# [29/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_93ec8b84_nohash_0.wav
# [30/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42817207_chunk007.wav
# [31/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_a7545b9f_nohash_1.wav
# [32/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710856_chunk006.wav
# [33/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43421856_chunk002.wav
# [34/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43215219_chunk009.wav
# [35/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1645_negative_background.wav
# [36/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_439c84f4_nohash_1.wav
# [37/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42712822_chunk002.wav
# [38/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_6a27a9bf_nohash_0.wav
# [39/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5833_negative_background.wav
# [40/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5216_negative_background.wav
# [41/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_b87bdb22_nohash_1.wav
# [42/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713206_chunk003.wav
# [43/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_97f4c236_nohash_2.wav
# [44/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43173958_chunk004.wav
# [45/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2658_negative_background.wav
# [46/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_563aa4e6_nohash_2.wav
# [47/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42701134_chunk001.wav
# [48/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4404_negative_background.wav
# [49/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2354_negative_background.wav
# [50/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713247_chunk005.wav
# [51/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_51055bda_nohash_4.wav
# [52/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42701120_chunk007.wav
# [53/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2971_negative_background.wav
# [54/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4108_negative_background.wav
# [55/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713212_chunk005.wav
# [56/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_a8cb6dda_nohash_0.wav
# [57/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3546_negative_background.wav
# [58/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_5fe4a278_nohash_0.wav
# [59/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43173919_chunk002.wav
# [60/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710548_chunk003.wav
# [61/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_e4a2cf79_nohash_0.wav
# [62/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2193_negative_background.wav
# [63/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_dabf67d9_nohash_0.wav
# [64/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3781_negative_background.wav
# [65/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713274_chunk008.wav
# [66/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1535_negative_background.wav
# [67/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_742d6431_nohash_3.wav
# [68/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_62581901_nohash_0.wav
# [69/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710509_chunk005.wav
# [70/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6477_negative_background.wav
# [71/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710644_chunk001.wav
# [72/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706142_chunk006.wav
# [73/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415502_chunk002.wav
# [74/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4353_negative_background.wav
# [75/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418206_chunk003.wav
# [76/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713365_chunk005.wav
# [77/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4976_negative_background.wav
# [78/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710611_chunk001.wav
# [79/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5541_negative_background.wav
# [80/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42816954_chunk006.wav
# [81/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415557_chunk002.wav
# [82/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713330_chunk005.wav
# [83/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3834_negative_background.wav
# [84/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415543_chunk004.wav
# [85/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3211_negative_background.wav
# [86/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713371_chunk003.wav
# [87/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_bf8d5617_nohash_0.wav
# [88/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2403_negative_background.wav
# [89/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_f852895b_nohash_2.wav
# [90/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1847_negative_background.wav
# [91/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706508_chunk001.wav
# [92/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42712840_chunk007.wav
# [93/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4498_negative_background.wav
# [94/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43421861_chunk007.wav
# [95/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710495_chunk003.wav
# [96/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43215657_chunk006.wav
# [97/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_229978fd_nohash_3.wav
# [98/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4194_negative_background.wav
# [99/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6320_negative_background.wav
# [100/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42712854_chunk001.wav
# [101/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43416258_chunk004.wav
# [102/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5786_negative_background.wav
# [103/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713400_chunk003.wav
# [104/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3161_negative_background.wav
# [105/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710704_chunk004.wav
# [106/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5918_negative_background.wav
# [107/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_a5609cce_nohash_0.wav
# [108/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706057_chunk003.wav
# [109/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2773_negative_background.wav
# [110/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_cab100c9_nohash_1.wav
# [111/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42701117_chunk002.wav
# [112/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43173990_chunk001.wav
# [113/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42698963_chunk001.wav
# [114/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6297_negative_background.wav
# [115/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4023_negative_background.wav
# [116/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713231_chunk006.wav
# [117/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_686d030b_nohash_1.wav
# [118/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5631_negative_background.wav
# [119/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6050_negative_background.wav
# [120/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_aef8dcf5_nohash_0.wav
# [121/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418129_chunk002.wav
# [122/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418197_chunk004.wav
# [123/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_8012c69d_nohash_3.wav
# [124/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42712900_chunk002.wav
# [125/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43419863_chunk004.wav
# [126/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418168_chunk004.wav
# [127/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_dc75148d_nohash_0.wav
# [128/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3983_negative_background.wav
# [129/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3723_negative_background.wav
# [130/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1597_negative_background.wav
# [131/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710621_chunk004.wav
# [132/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_31583d30_nohash_0.wav
# [133/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4948_negative_background.wav
# [134/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706172_chunk003.wav
# [135/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2131_negative_background.wav
# [136/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710674_chunk004.wav
# [137/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_8134f43f_nohash_0.wav
# [138/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706199_chunk005.wav
# [139/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording131.wav
# [140/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43214793_chunk002.wav
# [141/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4661_negative_background.wav
# [142/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710660_chunk002.wav
# [143/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_ffd2ba2f_nohash_4.wav
# [144/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706166_chunk005.wav
# [145/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43214778_chunk004.wav
# [146/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415526_chunk001.wav
# [147/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42817084_chunk005.wav
# [148/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710635_chunk002.wav
# [149/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706999_chunk010.wav
# [150/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706133_chunk005.wav
# [151/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5073_negative_background.wav
# [152/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42711335_chunk002.wav
# [153/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_bdb26021_nohash_1.wav
# [154/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706999_chunk004.wav
# [155/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording505_hard_negative.wav
# [156/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording125.wav
# [157/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42816916_chunk008.wav
# [158/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1879_negative_background.wav
# [159/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42712825_chunk002.wav
# [160/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5891_negative_background.wav
# [161/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43419559_chunk002.wav
# [162/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43421810_chunk004.wav
# [163/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1750_negative_background.wav
# [164/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42817200_chunk007.wav
# [165/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713190_chunk004.wav
# [166/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4511_negative_background.wav
# [167/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713240_chunk005.wav
# [168/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_712e4d58_nohash_2.wav
# [169/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5303_negative_background.wav
# [170/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_5ab63b0a_nohash_0.wav
# [171/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5926_negative_background.wav
# [172/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713215_chunk005.wav
# [173/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_1ba20be2_nohash_1.wav
# [174/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_a6d586b7_nohash_1.wav
# [175/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713201_chunk003.wav
# [176/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3453_negative_background.wav
# [177/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710720_chunk007.wav
# [178/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2864_negative_background.wav
# [179/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42701133_chunk001.wav
# [180/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2241_negative_background.wav
# [181/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording119.wav
# [182/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3694_negative_background.wav
# [183/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_9b402bc2_nohash_3.wav
# [184/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706208_chunk002.wav
# [185/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_1a4259c3_nohash_2.wav
# [186/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2086_negative_background.wav
# [187/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_57376a4c_nohash_1.wav
# [188/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418119_chunk007.wav
# [189/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710720_chunk013.wav
# [190/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6562_negative_background.wav
# [191/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3398_negative_background.wav
# [192/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418158_chunk001.wav
# [193/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_c0445658_nohash_4.wav
# [194/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415544_chunk004.wav
# [195/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3608_negative_background.wav
# [196/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5454_negative_background.wav
# [197/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42817058_chunk006.wav
# [198/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713323_chunk003.wav
# [199/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording30.wav
# [200/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415511_chunk004.wav
# [201/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43419378_chunk009.wav
# [202/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710657_chunk007.wav
# [203/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_e1469561_nohash_1.wav
# [204/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4863_negative_background.wav
# [205/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_e3e49931_nohash_0.wav
# [206/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418215_chunk005.wav
# [207/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4246_negative_background.wav
# [208/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713362_chunk005.wav
# [209/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2516_negative_background.wav
# [210/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_36050ef3_nohash_4.wav
# [211/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42816906_chunk006.wav
# [212/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706145_chunk006.wav
# [213/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_1b63157b_nohash_1.wav
# [214/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710643_chunk001.wav
# [215/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713389_chunk003.wav
# [216/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_c1d39ce8_nohash_6.wav
# [217/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713337_chunk005.wav
# [218/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3304_negative_background.wav
# [219/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710616_chunk001.wav
# [220/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5158_negative_background.wav
# [221/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415550_chunk002.wav
# [222/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3921_negative_background.wav
# [223/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42712853_chunk001.wav
# [224/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713304_chunk008.wav
# [225/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710486_chunk005.wav
# [226/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710438_chunk003.wav
# [227/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1952_negative_background.wav
# [228/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5693_negative_background.wav
# [229/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_9080f6d3_nohash_0.wav
# [230/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710492_chunk003.wav
# [231/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6235_negative_background.wav
# [232/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4081_negative_background.wav
# [233/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording24.wav
# [234/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43173968_chunk001.wav
# [235/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43173983_chunk007.wav
# [236/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2666_negative_background.wav
# [237/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5228_negative_background.wav
# [238/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3074_negative_background.wav
# [239/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5724_negative_background.wav
# [240/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_9aa21fa9_nohash_1.wav
# [241/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3578_negative_background.wav
# [242/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710703_chunk004.wav
# [243/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4136_negative_background.wav
# [244/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6382_negative_background.wav
# [245/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42700096_chunk008.wav
# [246/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706050_chunk003.wav
# [247/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6145_negative_background.wav
# [248/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording18.wav
# [249/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_0e17f595_nohash_1.wav
# [250/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6449_negative_background.wav
# [251/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_1b755c65_nohash_0.wav
# [252/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3896_negative_background.wav
# [253/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_6ef76186_nohash_0.wav
# [254/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_5c8af87a_nohash_0.wav
# [255/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43421857_chunk005.wav
# [256/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710857_chunk001.wav
# [257/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2702_negative_background.wav
# [258/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43215675_chunk002.wav
# [259/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42712823_chunk005.wav
# [260/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1981_negative_background.wav
# [261/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_b8c48ffb_nohash_0.wav
# [262/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording563_hard_negative.wav
# [263/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3110_negative_background.wav
# [264/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5969_negative_background.wav
# [265/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5640_negative_background.wav
# [266/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42712837_chunk003.wav
# [267/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43215259_chunk008.wav
# [268/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4052_negative_background.wav
# [269/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713196_chunk003.wav
# [270/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706121_chunk004.wav
# [271/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_ba770f9b_nohash_0.wav
# [272/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710627_chunk003.wav
# [273/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_76424fa5_nohash_0.wav
# [274/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5487_negative_background.wav
# [275/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713306_chunk007.wav
# [276/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706174_chunk004.wav
# [277/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710672_chunk003.wav
# [278/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42707474_chunk004.wav
# [279/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4295_negative_background.wav
# [280/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42817028_chunk002.wav
# [281/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6021_negative_background.wav
# [282/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43214781_chunk003.wav
# [283/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43214795_chunk005.wav
# [284/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713347_chunk001.wav
# [285/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415520_chunk006.wav
# [286/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710666_chunk005.wav
# [287/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4799_negative_background.wav
# [288/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_7fd25f7c_nohash_2.wav
# [289/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706160_chunk002.wav
# [290/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42711333_chunk005.wav
# [291/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710633_chunk005.wav
# [292/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706135_chunk002.wav
# [293/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710508_chunk002.wav
# [294/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42700080_chunk001.wav
# [295/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5530_negative_background.wav
# [296/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_c634a189_nohash_4.wav
# [297/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4907_negative_background.wav
# [298/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6196_negative_background.wav
# [299/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4322_negative_background.wav
# [300/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2472_negative_background.wav
# [301/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710549_chunk004.wav
# [302/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3260_negative_background.wav
# [303/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_3aa6f4e2_nohash_0.wav
# [304/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3845_negative_background.wav
# [305/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_84bf12ff_nohash_0.wav
# [306/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_9a4d12fd_nohash_1.wav
# [307/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713246_chunk002.wav
# [308/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1836_negative_background.wav
# [309/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43173918_chunk005.wav
# [310/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713213_chunk002.wav
# [311/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713207_chunk004.wav
# [312/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_299c14b1_nohash_0.wav
# [313/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6351_negative_background.wav
# [314/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713252_chunk004.wav
# [315/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42701135_chunk006.wav
# [316/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_f810e799_nohash_1.wav
# [317/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43173959_chunk003.wav
# [318/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_0f7205ef_nohash_0.wav
# [319/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42712855_chunk006.wav
# [320/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4475_negative_background.wav
# [321/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2629_negative_background.wav
# [322/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43215656_chunk001.wav
# [323/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_31d68957_nohash_0.wav
# [324/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5267_negative_background.wav
# [325/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42699929_chunk002.wav
# [326/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5842_negative_background.wav
# [327/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43416259_chunk003.wav
# [328/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_ac7840d8_nohash_0.wav
# [329/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_cb164eea_nohash_1.wav
# [330/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706509_chunk006.wav
# [331/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1783_negative_background.wav
# [332/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3537_negative_background.wav
# [333/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2900_negative_background.wav
# [334/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4179_negative_background.wav
# [335/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710494_chunk004.wav
# [336/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2325_negative_background.wav
# [337/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1544_negative_background.wav
# [338/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42816941_chunk007.wav
# [339/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415542_chunk003.wav
# [340/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713325_chunk004.wav
# [341/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706157_chunk007.wav
# [342/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_0c5027de_nohash_1.wav
# [343/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713364_chunk002.wav
# [344/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418207_chunk004.wav
# [345/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415503_chunk005.wav
# [346/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6406_negative_background.wav
# [347/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706143_chunk001.wav
# [348/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713331_chunk002.wav
# [349/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415556_chunk005.wav
# [350/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42816955_chunk001.wav
# [351/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710610_chunk006.wav
# [352/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3647_negative_background.wav
# [353/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_f104f742_nohash_1.wav
# [354/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_b0bad4a9_nohash_0.wav
# [355/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418169_chunk003.wav
# [356/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706056_chunk010.wav
# [357/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2055_negative_background.wav
# [358/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4209_negative_background.wav
# [359/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_d90b4138_nohash_4.wav
# [360/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418128_chunk005.wav
# [361/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2559_negative_background.wav
# [362/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4705_negative_background.wav
# [363/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_FalsePositive_20251030_231352_0.5766.wav
# [364/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42712901_chunk005.wav
# [365/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418196_chunk003.wav
# ...
# [16178/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42816957_chunk003.wav
# [16179/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_e62056e2_nohash_0.wav
# [16180/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710612_chunk004.wav
# [16181/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42817048_chunk005.wav
# [16182/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_338dacf5_nohash_2.wav
# [16183/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_c9b653a0_nohash_3.wav
# [16184/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2040_negative_background.wav
# [16185/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4839_negative_background.wav
# [16186/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_a4e8a997_nohash_1.wav
# [16187/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42700091_chunk005.wav
# [16188/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_ad63d93c_nohash_0.wav
# [16189/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_cc592808_nohash_0.wav
# [16190/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710519_chunk006.wav
# [16191/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3652_negative_background.wav
# [16192/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_c2aeb59d_nohash_0.wav
# [16193/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5102_negative_background.wav
# [16194/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_a97017df_nohash_2.wav
# [16195/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4710_negative_background.wav
# [16196/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3199_negative_background.wav
# [16197/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713202_chunk006.wav
# [16198/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1908_negative_background.wav
# [16199/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710723_chunk002.wav
# [16200/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43173909_chunk001.wav
# [16201/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2287_negative_background.wav
# [16202/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418168_chunk009.wav
# [16203/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3495_negative_background.wav
# [16204/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1621_negative_background.wav
# [16205/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42816899_chunk005.wav
# [16206/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_FalsePositive_20251030_231404_0.5836.wav
# [16207/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43421813_chunk001.wav
# [16208/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5857_negative_background.wav
# [16209/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_10c6d873_nohash_0.wav
# [16210/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_1bb6ed89_nohash_3.wav
# [16211/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5272_negative_background.wav
# [16212/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_333784b7_nohash_1.wav
# [16213/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42817203_chunk002.wav
# [16214/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710459_chunk003.wav
# [16215/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4460_negative_background.wav
# [16216/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713193_chunk001.wav
# [16217/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2330_negative_background.wav
# [16218/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2915_negative_background.wav
# [16219/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42712826_chunk007.wav
# [16220/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1796_negative_background.wav
# [16221/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3522_negative_background.wav
# [16222/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43421807_chunk007.wav
# [16223/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording621_hard_negative.wav
# [16224/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_1c6e5447_nohash_2.wav
# [16225/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42817039_chunk006.wav
# [16226/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710688_chunk001.wav
# [16227/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710663_chunk007.wav
# [16228/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713317_chunk003.wav
# [16229/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1551_negative_background.wav
# [16230/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710636_chunk007.wav
# [16231/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710622_chunk001.wav
# [16232/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713303_chunk005.wav
# [16233/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710677_chunk001.wav
# [16234/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706171_chunk006.wav
# [16235/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6413_negative_background.wav
# [16236/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_7cbf645a_nohash_0.wav
# [16237/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43214784_chunk001.wav
# [16238/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42699893_chunk005.wav
# [16239/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6183_negative_background.wav
# [16240/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4337_negative_background.wav
# [16241/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4912_negative_background.wav
# [16242/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5525_negative_background.wav
# [16243/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43418178_chunk007.wav
# [16244/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3779_negative_background.wav
# [16245/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3850_negative_background.wav
# [16246/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5029_negative_background.wav
# [16247/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43214829_chunk003.wav
# [16248/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706053_chunk012.wav
# [16249/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3275_negative_background.wav
# [16250/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42709328_chunk002.wav
# [16251/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_0c40e715_nohash_0.wav
# [16252/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2467_negative_background.wav
# [16253/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_c0c0d87d_nohash_0.wav
# [16254/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713221_chunk005.wav
# [16255/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710700_chunk001.wav
# [16256/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1823_negative_background.wav
# [16257/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713274_chunk005.wav
# [16258/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706053_chunk006.wav
# [16259/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42698998_chunk004.wav
# [16260/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording576_hard_negative.wav
# [16261/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43215597_chunk004.wav
# [16262/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2989_negative_background.wav
# [16263/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713260_chunk003.wav
# [16264/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43173980_chunk002.wav
# [16265/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6344_negative_background.wav
# [16266/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713235_chunk003.wav
# [16267/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_238c112c_nohash_0.wav
# [16268/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_2c7c33e8_nohash_0.wav
# [16269/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3105_negative_background.wav
# [16270/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5359_negative_background.wav
# [16271/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording1994_negative_background.wav
# [16272/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording2717_negative_background.wav
# [16273/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43215219_chunk010.wav
# [16274/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710491_chunk006.wav
# [16275/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4047_negative_background.wav
# [16276/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43215653_chunk003.wav
# [16277/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording3409_negative_background.wav
# [16278/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5655_negative_background.wav
# [16279/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording4280_negative_background.wav
# [16280/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6034_negative_background.wav
# [16281/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42703602_chunk005.wav
# [16282/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710640_chunk004.wav
# [16283/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42816905_chunk003.wav
# [16284/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706146_chunk003.wav
# [16285/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_c6389ab0_nohash_0.wav
# [16286/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording5492_negative_background.wav
# [16287/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415553_chunk007.wav
# [16288/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710615_chunk004.wav
# [16289/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415547_chunk001.wav
# [16290/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43215219_chunk004.wav
# [16291/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42713320_chunk006.wav
# [16292/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording538_hard_negative.wav
# [16293/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42706152_chunk005.wav
# [16294/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_test_recording6538_negative_background.wav
# [16295/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_42710654_chunk002.wav
# [16296/16296] Augmented and saved: /Users/sethwright/Documents/audio-model/data/Training_NEG/aug_common_voice_en_43415512_chunk001.wav

# %%
print (musan_dir)
# Out:
# /Users/sethwright/Downloads/musan

# %%
import os
import librosa
import soundfile as sf
import numpy as np

def convert_and_split_mp3s(
    input_dir = "/Users/sethwright/Downloads/archive/_background_noise_"    ,
    output_dir = "/Users/sethwright/Documents/audio-model/data/background_data" ,
    sample_rate=16000,
    clip_duration=1.25,
    overlap_duration=0.25
):
    """
    Convert all MP3 files in input_dir into fixed-length WAV clips with optional overlap.

    Each MP3 file is:
        1. Loaded and resampled to mono at `sample_rate`
        2. Split into clips of `clip_duration` seconds
        3. Adjacent clips overlap by `overlap_duration` seconds
        4. The final clip is zero-padded if it's shorter than `clip_duration`
        5. Saved as individual .wav files in output_dir

    Parameters
    ----------
    input_dir : str
        Folder containing source .mp3 files.
    output_dir : str
        Destination folder for processed .wav clips.
    sample_rate : int, default=16000
        Target sampling rate (Hz).
    clip_duration : float, default=1.25
        Duration (seconds) of each output audio chunk.
    overlap_duration : float, default=0.25
        Overlap (seconds) between consecutive clips.
        Example: 1.25 s clips with 0.25 s overlap → step = 1.00 s.
    """

    os.makedirs(output_dir, exist_ok=True)
    
    # Convert durations to samples
    clip_samples = int(sample_rate * clip_duration)
    overlap_samples = int(sample_rate * overlap_duration)
    step_size = clip_samples - overlap_samples  # how far we move forward each chunk

    # Walk through all files in the input directory
    for root, _, files in os.walk(input_dir):
        for fname in files:
            if not fname.lower().endswith(".wav"):
                continue

            in_path = os.path.join(root, fname)
            base_name = os.path.splitext(fname)[0]

            try:
                # -------------------------------------------------------
                # 1️⃣ Load audio (mono, 16 kHz)
                # -------------------------------------------------------
                y, sr = librosa.load(in_path, sr=sample_rate, mono=True)
                total_samples = len(y)

                # -------------------------------------------------------
                # 2️⃣ Compute how many clips will be produced
                # -------------------------------------------------------
                num_chunks = int(np.ceil((total_samples - overlap_samples) / step_size))

                # -------------------------------------------------------
                # 3️⃣ Split into overlapping chunks
                # -------------------------------------------------------
                for i in range(num_chunks):
                    start = i * step_size
                    end = start + clip_samples
                    clip = y[start:end]

                    # Pad the last clip with zeros if too short
                    if len(clip) < clip_samples:
                        clip = np.pad(clip, (0, clip_samples - len(clip)))

                    # Output filename: base_chunk001.wav
                    out_name = f"{base_name}_chunk{i+1:03d}.wav"
                    out_path = os.path.join(output_dir, out_name)

                    # ---------------------------------------------------
                    # 4️⃣ Save WAV file (float32 → 16-bit PCM)
                    # ---------------------------------------------------
                    sf.write(out_path, clip, sample_rate, subtype='PCM_16')

                print(f"✅ {fname}: {num_chunks} clips created")

            except Exception as e:
                print(f"❌ Error processing {fname}: {e}")

    print("\n🎉 All files converted and split successfully!")

# %%
convert_and_split_mp3s()

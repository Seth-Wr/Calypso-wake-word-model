# %%
import os
import random
import torch
import torchaudio
import numpy as np
import librosa
import soundfile as sf

# Target sample rate
TARGET_SAMPLE_RATE = 16000

# Function to load all MUSAN noise files
def load_musan_noises(musan_dir):
    noise_files = []
    for subdir in ['noise', 'music', 'speech']:
        subpath = os.path.join(musan_dir, subdir)
        if os.path.exists(subpath):
            for file in os.listdir(subpath):
                if file.endswith('.wav'):
                    noise_files.append(os.path.join(subpath, file))
    return noise_files

# Function to add random MUSAN background noise
def add_background_noise(signal, sample_rate, noise_files, snr_db_range=(0, 15)):
    if not noise_files:
        return signal
    
    # Randomly select a noise file
    noise_path = random.choice(noise_files)
    noise, noise_sr = torchaudio.load(noise_path)
    
    # Resample noise to 16000 Hz if needed
    if noise_sr != sample_rate:
        noise = torchaudio.transforms.Resample(noise_sr, sample_rate)(noise)
    
    # Trim or pad noise to match signal length
    sig_len = signal.shape[1]
    noise_len = noise.shape[1]
    if noise_len > sig_len:
        start = random.randint(0, noise_len - sig_len)
        noise = noise[:, start:start + sig_len]
    elif noise_len < sig_len:
        pad_left = random.randint(0, sig_len - noise_len)
        pad_right = sig_len - noise_len - pad_left
        noise = torch.nn.functional.pad(noise, (pad_left, pad_right))
    
    # Compute SNR and mix
    snr_db = random.uniform(*snr_db_range)
    signal_power = torch.mean(signal**2)
    noise_power = torch.mean(noise**2)
    factor = torch.sqrt(signal_power / (noise_power * 10**(snr_db / 10)))
    noise = noise * factor
    augmented = signal + noise
    return augmented / torch.max(torch.abs(augmented))  # Normalize to avoid clipping

# Function to apply time stretch using librosa
def time_stretch(signal, sample_rate, rate):
    # Convert torch tensor to numpy for librosa
    signal_np = signal.numpy().flatten()
    # Apply time stretch
    stretched = librosa.effects.time_stretch(signal_np, rate=rate)
    # Convert back to torch tensor
    stretched = torch.tensor(stretched, dtype=torch.float32).unsqueeze(0)
    return stretched

# Function to apply gain manually (replacing apply_gain)
def apply_manual_gain(signal, gain_db):
    # Convert dB to linear gain
    gain_linear = 10 ** (gain_db / 20)
    return signal * gain_linear

# Function to apply effective augmentations
def augment_audio(audio_path, musan_noises, output_dir):
    # Load audio (assumed to be 16000 Hz)
    signal, orig_sr = torchaudio.load(audio_path)
    if orig_sr != TARGET_SAMPLE_RATE:
        print(f"Warning: {audio_path} has sample rate {orig_sr}. Expected 16000 Hz. Resampling.")
        signal = torchaudio.transforms.Resample(orig_sr, TARGET_SAMPLE_RATE)(signal)
    
    # Add MUSAN background noise (50% chance)
    if random.random() < 0.5:
        signal = add_background_noise(signal, TARGET_SAMPLE_RATE, musan_noises)
    
    # Pitch shift (-4 to +4 semitones, 50% chance)
    if random.random() < 0.5:
        pitch_shift = random.uniform(-4, 4)
        signal = torchaudio.functional.pitch_shift(signal, TARGET_SAMPLE_RATE, n_steps=pitch_shift)
    
    # Time stretch (0.8–1.2 speed, 50% chance)
    if random.random() < 0.5:
        rate = random.uniform(0.8, 1.2)
        signal = time_stretch(signal, TARGET_SAMPLE_RATE, rate)
    
    # Gain (-6 to +6 dB, 50% chance)
    if random.random() < 0.5:
        gain_db = random.uniform(-6, 6)
        signal = apply_manual_gain(signal, gain_db)
    
    # Gaussian noise (low amplitude, 30% chance)
    if random.random() < 0.3:
        noise = torch.normal(0, random.uniform(0.001, 0.015), signal.shape)
        signal = signal + noise
        signal = signal / torch.max(torch.abs(signal))  # Normalize
    
    # Save augmented file
    base_name = os.path.basename(audio_path)
    output_path = os.path.join(output_dir, f"aug_{base_name}")
    # Convert to numpy for soundfile
    signal_np = signal.numpy().flatten()
    sf.write(output_path, signal_np, TARGET_SAMPLE_RATE)
    return output_path

# Main script
def main(input_dir, musan_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    musan_noises = load_musan_noises(musan_dir)
    if not musan_noises:
        print("Warning: No MUSAN noise files found. Skipping background noise augmentation.")
    
    wav_files = [f for f in os.listdir(input_dir) if f.endswith('.wav')]
    for wav_file in wav_files:
        audio_path = os.path.join(input_dir, wav_file)
        augmented_path = augment_audio(audio_path, musan_noises, output_dir)
        print(f"Augmented and saved: {augmented_path}")


# Example usage (replace with your paths)
if __name__ == "__main__":
    MUSAN_DIR = "/Users/sethwright/Downloads/musan"    
    input_dir = "/Users/sethwright/Documents/audio-model/data/negative_1"  # Folder with your WAV files

    output_dir = "/Users/sethwright/Documents/audio-model/data/augmentedneg_data"   # Where to save augmented files
    main(input_dir, MUSAN_DIR, output_dir)
# Out:
# Warning: No MUSAN noise files found. Skipping background noise augmentation.
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1383.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1397.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1340.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1426.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1432.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1354.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1368.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1181.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1195.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1624.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1142.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1156.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1630.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1618.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording938.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1036.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1022.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording904.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording910.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1591.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1585.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1234.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1552.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1546.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1220.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1208.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1209.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1547.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1221.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1235.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1553.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1584.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1590.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording911.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording905.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1023.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording939.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1037.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1619.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1157.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1631.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1625.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1143.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1194.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1180.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1369.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1433.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1355.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1341.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1427.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1396.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1382.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1394.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1380.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1357.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1431.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1425.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1343.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1419.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1196.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1182.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1155.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1141.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1627.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1169.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1021.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1035.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording913.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1009.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording907.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1586.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1592.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1223.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1545.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1551.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1237.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1579.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1578.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1550.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1236.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1222.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1544.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1593.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1587.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1008.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording906.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording912.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1034.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1020.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1168.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1140.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1626.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1154.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1183.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1197.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1418.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1424.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1342.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1356.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1430.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1381.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1395.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1391.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1385.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1408.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1434.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1352.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1346.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1420.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1193.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1187.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1178.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1150.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1622.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1144.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1018.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording916.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording902.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1024.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1030.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1583.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1597.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1568.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1540.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1226.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1232.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1554.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1233.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1555.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1541.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1227.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1569.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1596.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1582.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1031.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1025.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording903.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1019.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording917.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1623.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1145.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1151.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1179.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1186.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1192.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1347.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1421.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1435.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1353.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1409.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1384.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1390.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1386.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1392.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1379.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1423.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1345.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1351.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1437.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1184.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1190.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1609.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1147.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1621.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1153.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording901.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording915.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1033.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording929.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1027.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1594.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1580.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1219.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1557.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1231.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1225.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1543.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1224.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1542.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1556.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1230.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1218.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1581.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1595.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording928.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1026.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1032.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording914.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1152.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1146.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1620.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1608.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1191.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1185.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1350.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1436.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1422.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1344.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1378.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1393.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1387.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1486.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1492.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1445.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1323.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1337.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1451.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1479.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1121.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1135.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1109.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1096.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording998.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1082.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1055.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1041.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1069.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording967.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording973.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1294.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1280.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1531.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1257.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1243.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1525.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1519.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1518.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1242.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1524.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1530.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1256.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1281.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1295.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording972.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1068.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording966.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1040.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1054.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1083.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1097.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording999.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1108.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1134.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1120.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1478.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1336.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1450.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1444.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1322.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1493.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1487.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1491.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1485.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1452.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1334.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1320.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1446.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1308.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1136.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1122.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1081.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1095.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1042.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording958.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1056.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording970.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording964.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1283.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1297.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1526.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1240.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1254.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1532.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1268.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1269.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1255.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1533.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1527.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1241.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1296.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1282.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording965.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording971.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording959.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1057.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1043.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1094.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1080.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1123.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1137.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1309.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1321.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1447.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1453.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1335.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1484.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1490.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1494.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1480.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1319.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1331.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1457.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1443.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1325.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1133.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1127.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1084.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1090.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording975.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording961.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording949.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1047.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1053.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1286.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1292.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1279.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1245.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1523.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1537.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1251.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1536.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1250.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1244.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1522.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1278.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1293.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1287.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1052.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording948.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1046.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording960.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording974.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1091.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1085.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1126.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1132.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1442.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1324.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1330.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1456.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1318.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1481.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1495.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1483.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1497.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1468.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1326.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1440.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1454.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1332.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1118.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1124.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1130.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1093.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1087.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording989.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording962.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1078.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording976.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1050.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1044.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1291.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1285.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1508.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1252.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1534.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1520.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1246.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1521.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1247.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1253.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1535.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1509.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1284.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1290.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1045.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1051.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1079.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording977.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording963.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1086.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording988.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1092.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1131.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1125.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1119.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1455.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1333.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1327.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1441.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1469.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1496.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1482.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1464.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1302.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1316.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1470.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1458.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1100.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1114.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1128.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording985.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording991.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1074.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1060.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1048.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording946.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording952.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1289.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1510.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1276.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1262.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1504.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1538.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1539.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1263.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1505.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1511.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1277.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1288.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording953.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1049.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording947.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1061.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1075.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording990.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording984.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1129.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1115.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1101.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1459.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1317.wav
# ...
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1599.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording930.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording924.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1002.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording918.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1016.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1176.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1610.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1604.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1162.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1189.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1348.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1412.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1374.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1360.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1406.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1389.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1376.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1410.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1404.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1362.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1438.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1612.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1174.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1160.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1606.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1148.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1000.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1014.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording932.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1028.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording926.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1202.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1564.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1570.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1216.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1558.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1559.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1571.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1217.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1203.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1565.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1029.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording927.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording933.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1015.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1001.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1149.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1161.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1607.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1613.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1175.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1439.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1405.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1363.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1377.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1411.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1388.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1398.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1429.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1415.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1373.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1367.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1401.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1159.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1171.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1617.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1603.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1165.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1039.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording937.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording923.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1005.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1011.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1549.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1561.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1207.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1213.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1575.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1212.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1574.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1560.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1206.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1548.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1010.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1004.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording922.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1038.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording936.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1602.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1164.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1170.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1616.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1158.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1366.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1400.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1414.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1372.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1428.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1399.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1358.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1402.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1364.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1370.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1416.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1199.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1628.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1166.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1600.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1614.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1172.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording920.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording934.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1012.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording908.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1006.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1589.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1238.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1576.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1210.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1204.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1562.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1205.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1563.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1577.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1211.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1239.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1588.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording909.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1007.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1013.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording935.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording921.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1615.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1173.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1167.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1601.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1629.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1198.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1371.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1417.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1403.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1365.wav
# Augmented and saved: /Users/sethwright/Documents/audio-model/data/augmentedneg_data/aug_test_recording1359.wav
